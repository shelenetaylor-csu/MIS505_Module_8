# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

un_df = pd.read_csv("../Module_8/API_SE.PRM.ENRL_DS2_en_csv_v2_4538564.csv", skiprows=3)
wdi_df = pd.read_csv("../Module_8/WDIData.csv")
pd.options.display.float_format = "{:.2f}".format
wdi_df2 = wdi_df.loc[(wdi_df["Country Code"] == "ZWE") & (wdi_df["Indicator Code"] == "NY.GDP.MKTP.CD")]

# %%
# un_df.head()
print(list(un_df.columns))
# un_df.shape
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', 'Unnamed: 66']

# %%
un_df2 = un_df.drop(['Indicator Name', 'Indicator Code'], axis=1)
# un_df2['Country Name'] == 'Zimbabwe'
# un_df2['Country Name'][265]
# un_df2
un_df2.set_index("Country Code")
my_country = un_df2.loc[un_df2["Country Code"] == "ZWE"].iloc[0, 2:].reset_index(name="Population").rename(columns={"index": "Year"})
# my_country_not_null = my_country["Population"
print(type(my_country))
# my_country_without_null = my_country.copy()
my_country_without_null["Population"] = (my_country["Population"].fillna(my_country["Population"].mean()))
# pd.options.display.float_format = "{:.2f}".format
my_country_without_null.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 10
#       8 print(type(my_country))
#       9 # my_country_without_null = my_country.copy()
# ---> 10 my_country_without_null["Population"] = (my_country["Population"].fillna(my_country["Population"].mean()))
#      11 # pd.options.display.float_format = "{:.2f}".format
#      12 my_country_without_null.tail()
#
# NameError: name 'my_country_without_null' is not defined
